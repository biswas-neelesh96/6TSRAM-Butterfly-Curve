# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns
print('Setup Complete')
# Out:
# Setup Complete

# %%
data=pd.read_csv('Butterfly Curve.csv')
data.tail()
# Out:
#      VV1[Volts]    Q:V[Volts]  Qb:V[Volts]
# 96         0.96  6.196354e-07         0.96
# 97         0.97  4.592522e-07         0.97
# 98         0.98  3.404977e-07         0.98
# 99         0.99  2.525856e-07         0.99
# 100        1.00  1.875160e-07         1.00

# %%
plt.figure(figsize=(16,6))
plt.title("6T SRAM Butterfly Curve")
plt.xlabel("V1(Volts)")
plt.ylabel('Q')
sns.lineplot(x=data['Qb:V[Volts]'], y=data['Q:V[Volts]'], label='I',color='red')
sns.lineplot(x=data['Q:V[Volts]'], y=data['Qb:V[Volts]'], label='II',color='green')
# Out:
# <Axes: title={'center': '6T SRAM Butterfly Curve'}, xlabel='V1(Volts)', ylabel='Q'>
