# %% [markdown]
# <a href="https://colab.research.google.com/github/biswas-neelesh96/6TSRAM-Butterfly-Curve/blob/main/6TSRAM_Butterfly_Curve.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from scipy.optimize import curve_fit
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns
print('Setup Complete')
# Out:
# Setup Complete

# %%
data=pd.read_csv('Butterfly Curve.csv')
data.tail()
# Out:
#      VV1[Volts]    Q:V[Volts]  Qb:V[Volts]
# 96         0.96  6.196354e-07         0.96
# 97         0.97  4.592522e-07         0.97
# 98         0.98  3.404977e-07         0.98
# 99         0.99  2.525856e-07         0.99
# 100        1.00  1.875160e-07         1.00

# %%
plt.figure(figsize=(16,6))
plt.title("6T SRAM Butterfly Curve")
plt.xlabel("V1(Volts)")
plt.ylabel('Q')
f1=sns.lineplot(x=data['Qb:V[Volts]'], y=data['Q:V[Volts]'], label='I',color='red')
f2=sns.lineplot(x=data['Q:V[Volts]'], y=data['Qb:V[Volts]'], label='II',color='green')
f3=sns.lineplot(x=data['VV1[Volts]'], y=data['Qb:V[Volts]'],label='line of symmetry', color='black', linestyle='dotted')
